# %% [markdown]
# <a href="https://colab.research.google.com/github/DEBMALYASEN/ABC/blob/master/summary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#TEXT SUMMARY

# %%
text="""World War II (often abbreviated as WWII or WW2), also known as the Second World War, was a global war that lasted from 1939 to 1945. The vast majority of the world's countries—including all the great powers—eventually formed two opposing military alliances: the Allies and the Axis. A state of total war emerged, directly involving more than 100 million people from more than 30 countries. The major participants threw their entire economic, industrial, and scientific capabilities behind the war effort, blurring the distinction between civilian and military resources. World War II was the deadliest conflict in human history, marked by 70 to 85 million fatalities. Tens of millions of people died during the conflict due to genocides (including the Holocaust), premeditated death from starvation, massacres, and disease. Aircraft played a major role in the conflict which included the use of terror bombing, strategic bombing and the only use of nuclear weapons in war.

World War II is generally said to have begun on 1 September 1939, with the invasion of Poland by Germany and subsequent declarations of war on Germany by France and the United Kingdom. From late 1939 to early 1941, in a series of campaigns and treaties, Germany conquered or controlled much of continental Europe, and formed the Axis alliance with Italy and Japan. Under the Molotov–Ribbentrop Pact of August 1939, Germany and the Soviet Union partitioned and annexed territories of their European neighbours, Poland, Finland, Romania and the Baltic states. Following the onset of campaigns in North Africa and East Africa, and the Fall of France in mid-1940, the war continued primarily between the European Axis powers and the British Empire. War in the Balkans, the aerial Battle of Britain, the Blitz, and the long Battle of the Atlantic followed. On 22 June 1941, the European Axis powers launched an invasion of the Soviet Union, opening the largest land theatre of war in history. This Eastern Front trapped the Axis, most crucially the German Wehrmacht, in a war of attrition.

In December 1941 Japan launched a surprise attack on the United States as well as European colonies in East Asia and the Pacific. Following an immediate US declaration of war against Japan, supported by one from Great Britain, the European Axis powers quickly declared war on the United States in solidarity with their Japanese ally. Japan soon captured much of the Western Pacific. Some in the region initially welcomed the Japanese as liberators from Western imperialism. Subsequent Japanese war crimes frequently turned local public opinion against the Japanese.[1] Japan's advances in the Pacific were halted in 1942 after defeats at the Battle of Midway, Battle of the Coral Sea and Battle of Guadalcanal; later, Germany and Italy were defeated in North Africa and then, decisively, at Stalingrad in the Soviet Union. Key setbacks in 1943—which included a series of German defeats on the Eastern Front, the Allied invasions of Sicily and Italy, and Allied offensives in the Pacific—cost the Axis its initiative and forced it into strategic retreat on all fronts. In 1944 the Western Allies invaded German-occupied France, while the Soviet Union regained its territorial losses and turned toward Germany and its allies. During 1944 and 1945 the Japanese suffered major reversals in mainland Asia, in Central China, South China and Burma, while the Allies crippled the Japanese Navy and captured key Western Pacific islands.

The war in Europe concluded with an invasion of Germany by the Western Allies and the Soviet Union, culminating in the capture of Berlin by Soviet troops, the suicide of Adolf Hitler and the German unconditional surrender on 8 May 1945. Following the Potsdam Declaration by the Allies on 26 July 1945 and the refusal of Japan to surrender under its terms, the United States dropped atomic bombs on the Japanese cities of Hiroshima and Nagasaki on 6 and 9 August, respectively. With an invasion of the Japanese archipelago imminent, the possibility of additional atomic bombings, the Soviet entry into the war against Japan and its invasion of Manchuria, Japan announced its intention to surrender on 15 August 1945, cementing total victory in Asia for the Allies. Tribunals were set up by the Allies, and war crimes trials were conducted in the wake of the war both against the Germans and against the Japanese.

World War II changed the political alignment and social structure of the globe. The United Nations (UN) was established to foster international co-operation and prevent future conflicts; the victorious great powers—China, France, the Soviet Union, the United Kingdom, and the United States—became the permanent members of its Security Council. The Soviet Union and the United States emerged as rival superpowers, setting the stage for the nearly half-century-long Cold War. In the wake of European devastation, the influence of its great powers waned, triggering the decolonisation of Africa and Asia. Most countries whose industries had been damaged moved towards economic recovery and expansion. Political integration, especially in Europe, began as an effort to forestall future hostilities, end pre-war enmities and forge a sense of common identity."""

# %%
pip install -U spacy
# Out:
# Collecting spacy
#   Downloading https://files.pythonhosted.org/packages/31/c7/e66e2af1cfa418c3a3917c116c4e00ccffa546f18f59e6acd7953d833c5c/spacy-2.3.0-cp36-cp36m-manylinux1_x86_64.whl (10.0MB)
#      |████████████████████████████████| 10.0MB 5.0MB/s
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (3.0.2)
# Collecting thinc==7.4.1
#   Downloading https://files.pythonhosted.org/packages/10/ae/ef3ae5e93639c0ef8e3eb32e3c18341e511b3c515fcfc603f4b808087651/thinc-7.4.1-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 41.3MB/s
# Requirement already satisfied, skipping upgrade: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied, skipping upgrade: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied, skipping upgrade: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy) (47.3.1)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.18.5)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied, skipping upgrade: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (1.6.1)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.9)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.1.0)
# Installing collected packages: thinc, spacy
#   Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed spacy-2.3.0 thinc-7.4.1

# %%
import spacy

from string import punctuation

# %%
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS

# %%
spacy_stopwords
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
nlp=spacy.load('en_core_web_sm')
# Out:
# /usr/local/lib/python3.6/dist-packages/spacy/util.py:271: UserWarning: [W031] Model 'en_core_web_sm' (2.2.5) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.0). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
doc=nlp(text)

# %%
doc
# Out:
# World War II (often abbreviated as WWII or WW2), also known as the Second World War, was a global war that lasted from 1939 to 1945. The vast majority of the world's countries—including all the great powers—eventually formed two opposing military alliances: the Allies and the Axis. A state of total war emerged, directly involving more than 100 million people from more than 30 countries. The major participants threw their entire economic, industrial, and scientific capabilities behind the war effort, blurring the distinction between civilian and military resources. World War II was the deadliest conflict in human history, marked by 70 to 85 million fatalities. Tens of millions of people died during the conflict due to genocides (including the Holocaust), premeditated death from starvation, massacres, and disease. Aircraft played a major role in the conflict which included the use of terror bombing, strategic bombing and the only use of nuclear weapons in war.
#
# World War II is generally said to have begun on 1 September 1939, with the invasion of Poland by Germany and subsequent declarations of war on Germany by France and the United Kingdom. From late 1939 to early 1941, in a series of campaigns and treaties, Germany conquered or controlled much of continental Europe, and formed the Axis alliance with Italy and Japan. Under the Molotov–Ribbentrop Pact of August 1939, Germany and the Soviet Union partitioned and annexed territories of their European neighbours, Poland, Finland, Romania and the Baltic states. Following the onset of campaigns in North Africa and East Africa, and the Fall of France in mid-1940, the war continued primarily between the European Axis powers and the British Empire. War in the Balkans, the aerial Battle of Britain, the Blitz, and the long Battle of the Atlantic followed. On 22 June 1941, the European Axis powers launched an invasion of the Soviet Union, opening the largest land theatre of war in history. This Eastern Front trapped the Axis, most crucially the German Wehrmacht, in a war of attrition.
#
# In December 1941 Japan launched a surprise attack on the United States as well as European colonies in East Asia and the Pacific. Following an immediate US declaration of war against Japan, supported by one from Great Britain, the European Axis powers quickly declared war on the United States in solidarity with their Japanese ally. Japan soon captured much of the Western Pacific. Some in the region initially welcomed the Japanese as liberators from Western imperialism. Subsequent Japanese war crimes frequently turned local public opinion against the Japanese.[1] Japan's advances in the Pacific were halted in 1942 after defeats at the Battle of Midway, Battle of the Coral Sea and Battle of Guadalcanal; later, Germany and Italy were defeated in North Africa and then, decisively, at Stalingrad in the Soviet Union. Key setbacks in 1943—which included a series of German defeats on the Eastern Front, the Allied invasions of Sicily and Italy, and Allied offensives in the Pacific—cost the Axis its initiative and forced it into strategic retreat on all fronts. In 1944 the Western Allies invaded German-occupied France, while the Soviet Union regained its territorial losses and turned toward Germany and its allies. During 1944 and 1945 the Japanese suffered major reversals in mainland Asia, in Central China, South China and Burma, while the Allies crippled the Japanese Navy and captured key Western Pacific islands.
#
# The war in Europe concluded with an invasion of Germany by the Western Allies and the Soviet Union, culminating in the capture of Berlin by Soviet troops, the suicide of Adolf Hitler and the German unconditional surrender on 8 May 1945. Following the Potsdam Declaration by the Allies on 26 July 1945 and the refusal of Japan to surrender under its terms, the United States dropped atomic bombs on the Japanese cities of Hiroshima and Nagasaki on 6 and 9 August, respectively. With an invasion of the Japanese archipelago imminent, the possibility of additional atomic bombings, the Soviet entry into the war against Japan and its invasion of Manchuria, Japan announced its intention to surrender on 15 August 1945, cementing total victory in Asia for the Allies. Tribunals were set up by the Allies, and war crimes trials were conducted in the wake of the war both against the Germans and against the Japanese.
#
# World War II changed the political alignment and social structure of the globe. The United Nations (UN) was established to foster international co-operation and prevent future conflicts; the victorious great powers—China, France, the Soviet Union, the United Kingdom, and the United States—became the permanent members of its Security Council. The Soviet Union and the United States emerged as rival superpowers, setting the stage for the nearly half-century-long Cold War. In the wake of European devastation, the influence of its great powers waned, triggering the decolonisation of Africa and Asia. Most countries whose industries had been damaged moved towards economic recovery and expansion. Political integration, especially in Europe, began as an effort to forestall future hostilities, end pre-war enmities and forge a sense of common identity.

# %%
tokens=[token.text for token in doc]

# %%
tokens
# Out:
# ['World',
#  'War',
#  'II',
#  '(',
#  'often',
#  'abbreviated',
#  'as',
#  'WWII',
#  'or',
#  'WW2',
#  ')',
#  ',',
#  'also',
#  'known',
#  'as',
#  'the',
#  'Second',
#  'World',
#  'War',
#  ',',
#  'was',
#  'a',
#  'global',
#  'war',
#  'that',
#  'lasted',
#  'from',
#  '1939',
#  'to',
#  '1945',
#  '.',
#  'The',
#  'vast',
#  'majority',
#  'of',
#  'the',
#  'world',
#  "'s",
#  'countries',
#  '—',
#  'including',
#  'all',
#  'the',
#  'great',
#  'powers',
#  '—',
#  'eventually',
#  'formed',
#  'two',
#  'opposing',
#  'military',
#  'alliances',
#  ':',
#  'the',
#  'Allies',
#  'and',
#  'the',
#  'Axis',
#  '.',
#  'A',
#  'state',
#  'of',
#  'total',
#  'war',
#  'emerged',
#  ',',
#  'directly',
#  'involving',
#  'more',
#  'than',
#  '100',
#  'million',
#  'people',
#  'from',
#  'more',
#  'than',
#  '30',
#  'countries',
#  '.',
#  'The',
#  'major',
#  'participants',
#  'threw',
#  'their',
#  'entire',
#  'economic',
#  ',',
#  'industrial',
#  ',',
#  'and',
#  'scientific',
#  'capabilities',
#  'behind',
#  'the',
#  'war',
#  'effort',
#  ',',
#  'blurring',
#  'the',
#  'distinction',
#  'between',
#  'civilian',
#  'and',
#  'military',
#  'resources',
#  '.',
#  'World',
#  'War',
#  'II',
#  'was',
#  'the',
#  'deadliest',
#  'conflict',
#  'in',
#  'human',
#  'history',
#  ',',
#  'marked',
#  'by',
#  '70',
#  'to',
#  '85',
#  'million',
#  'fatalities',
#  '.',
#  'Tens',
#  'of',
#  'millions',
#  'of',
#  'people',
#  'died',
#  'during',
#  'the',
#  'conflict',
#  'due',
#  'to',
#  'genocides',
#  '(',
#  'including',
#  'the',
#  'Holocaust',
#  ')',
#  ',',
#  'premeditated',
#  'death',
#  'from',
#  'starvation',
#  ',',
#  'massacres',
#  ',',
#  'and',
#  'disease',
#  '.',
#  'Aircraft',
#  'played',
#  'a',
#  'major',
#  'role',
#  'in',
#  'the',
#  'conflict',
#  'which',
#  'included',
#  'the',
#  'use',
#  'of',
#  'terror',
#  'bombing',
#  ',',
#  'strategic',
#  'bombing',
#  'and',
#  'the',
#  'only',
#  'use',
#  'of',
#  'nuclear',
#  'weapons',
#  'in',
#  'war',
#  '.',
#  '\n\n',
#  'World',
#  'War',
#  'II',
#  'is',
#  'generally',
#  'said',
#  'to',
#  'have',
#  'begun',
#  'on',
#  '1',
#  'September',
#  '1939',
#  ',',
#  'with',
#  'the',
#  'invasion',
#  'of',
#  'Poland',
#  'by',
#  'Germany',
#  'and',
#  'subsequent',
#  'declarations',
#  'of',
#  'war',
#  'on',
#  'Germany',
#  'by',
#  'France',
#  'and',
#  'the',
#  'United',
#  'Kingdom',
#  '.',
#  'From',
#  'late',
#  '1939',
#  'to',
#  'early',
#  '1941',
#  ',',
#  'in',
#  'a',
#  'series',
#  'of',
#  'campaigns',
#  'and',
#  'treaties',
#  ',',
#  'Germany',
#  'conquered',
#  'or',
#  'controlled',
#  'much',
#  'of',
#  'continental',
#  'Europe',
#  ',',
#  'and',
#  'formed',
#  'the',
#  'Axis',
#  'alliance',
#  'with',
#  'Italy',
#  'and',
#  'Japan',
#  '.',
#  'Under',
#  'the',
#  'Molotov',
#  '–',
#  'Ribbentrop',
#  'Pact',
#  'of',
#  'August',
#  '1939',
#  ',',
#  'Germany',
#  'and',
#  'the',
#  'Soviet',
#  'Union',
#  'partitioned',
#  'and',
#  'annexed',
#  'territories',
#  'of',
#  'their',
#  'European',
#  'neighbours',
#  ',',
#  'Poland',
#  ',',
#  'Finland',
#  ',',
#  'Romania',
#  'and',
#  'the',
#  'Baltic',
#  'states',
#  '.',
#  'Following',
#  'the',
#  'onset',
#  'of',
#  'campaigns',
#  'in',
#  'North',
#  'Africa',
#  'and',
#  'East',
#  'Africa',
#  ',',
#  'and',
#  'the',
#  'Fall',
#  'of',
#  'France',
#  'in',
#  'mid-1940',
#  ',',
#  'the',
#  'war',
#  'continued',
#  'primarily',
#  'between',
#  'the',
#  'European',
#  'Axis',
#  'powers',
#  'and',
#  'the',
#  'British',
#  'Empire',
#  '.',
#  'War',
#  'in',
#  'the',
#  'Balkans',
#  ',',
#  'the',
#  'aerial',
#  'Battle',
#  'of',
#  'Britain',
#  ',',
#  'the',
#  'Blitz',
#  ',',
#  'and',
#  'the',
#  'long',
#  'Battle',
#  'of',
#  'the',
#  'Atlantic',
#  'followed',
#  '.',
#  'On',
#  '22',
#  'June',
#  '1941',
#  ',',
#  'the',
#  'European',
#  'Axis',
#  'powers',
#  'launched',
#  'an',
#  'invasion',
#  'of',
#  'the',
#  'Soviet',
#  'Union',
#  ',',
#  'opening',
#  'the',
#  'largest',
#  'land',
#  'theatre',
#  'of',
#  'war',
#  'in',
#  'history',
#  '.',
#  'This',
#  'Eastern',
#  'Front',
#  'trapped',
#  'the',
#  'Axis',
#  ',',
#  'most',
#  'crucially',
#  'the',
#  'German',
#  'Wehrmacht',
#  ',',
#  'in',
#  'a',
#  'war',
#  'of',
#  'attrition',
#  '.',
#  '\n\n',
#  'In',
#  'December',
#  '1941',
#  'Japan',
#  'launched',
#  'a',
#  'surprise',
#  'attack',
#  'on',
#  'the',
#  'United',
#  'States',
#  'as',
#  'well',
#  'as',
#  'European',
#  'colonies',
#  'in',
#  'East',
#  'Asia',
#  'and',
#  'the',
#  'Pacific',
#  '.',
#  'Following',
#  'an',
#  'immediate',
#  'US',
#  'declaration',
#  'of',
#  'war',
#  'against',
#  'Japan',
#  ',',
#  'supported',
#  'by',
#  'one',
#  'from',
#  'Great',
#  'Britain',
#  ',',
#  'the',
#  'European',
#  'Axis',
#  'powers',
#  'quickly',
#  'declared',
#  'war',
#  'on',
#  'the',
#  'United',
#  'States',
#  'in',
#  'solidarity',
#  'with',
#  'their',
#  'Japanese',
#  'ally',
#  '.',
#  'Japan',
#  'soon',
#  'captured',
#  'much',
#  'of',
#  'the',
#  'Western',
#  'Pacific',
#  '.',
#  'Some',
#  'in',
#  'the',
#  'region',
#  'initially',
#  'welcomed',
#  'the',
#  'Japanese',
#  'as',
#  'liberators',
#  'from',
#  'Western',
#  'imperialism',
#  '.',
#  'Subsequent',
#  'Japanese',
#  'war',
#  'crimes',
#  'frequently',
#  'turned',
#  'local',
#  'public',
#  'opinion',
#  'against',
#  'the',
#  'Japanese.[1',
#  ']',
#  'Japan',
#  "'s",
#  'advances',
#  'in',
#  'the',
#  'Pacific',
#  'were',
#  'halted',
#  'in',
#  '1942',
#  'after',
#  'defeats',
#  'at',
#  'the',
#  'Battle',
#  'of',
#  'Midway',
#  ',',
#  'Battle',
#  'of',
#  'the',
#  'Coral',
#  'Sea',
#  'and',
#  'Battle',
#  'of',
#  'Guadalcanal',
#  ';',
#  'later',
#  ',',
#  'Germany',
#  'and',
#  'Italy',
#  'were',
#  'defeated',
#  'in',
#  'North',
#  'Africa',
#  'and',
#  'then',
#  ',',
#  'decisively',
#  ',',
#  'at',
#  'Stalingrad',
#  'in',
#  'the',
#  'Soviet',
#  'Union',
#  '.',
#  'Key',
#  'setbacks',
#  'in',
#  '1943—which',
#  'included',
#  'a',
#  'series',
#  'of',
#  'German',
#  'defeats',
#  'on',
#  'the',
#  'Eastern',
#  'Front',
#  ',',
#  'the',
#  'Allied',
#  'invasions',
#  'of',
#  'Sicily',
#  'and',
#  'Italy',
#  ',',
#  'and',
#  'Allied',
#  'offensives',
#  'in',
#  'the',
#  'Pacific',
#  '—',
#  'cost',
#  'the',
#  'Axis',
#  'its',
#  'initiative',
#  'and',
#  'forced',
#  'it',
#  'into',
#  'strategic',
#  'retreat',
#  'on',
#  'all',
#  'fronts',
#  '.',
#  'In',
#  '1944',
#  'the',
#  'Western',
#  'Allies',
#  'invaded',
#  'German',
#  '-',
#  'occupied',
#  'France',
#  ',',
#  'while',
#  'the',
#  'Soviet',
#  'Union',
#  'regained',
#  'its',
#  'territorial',
#  'losses',
#  'and',
#  'turned',
#  'toward',
#  'Germany',
#  'and',
#  'its',
#  'allies',
#  '.',
#  'During',
#  '1944',
#  'and',
#  '1945',
#  'the',
#  'Japanese',
#  'suffered',
#  'major',
#  'reversals',
#  'in',
#  'mainland',
#  'Asia',
#  ',',
#  'in',
#  'Central',
#  'China',
#  ',',
#  'South',
#  'China',
#  'and',
#  'Burma',
#  ',',
#  'while',
#  'the',
#  'Allies',
#  'crippled',
#  'the',
#  'Japanese',
#  'Navy',
#  'and',
#  'captured',
#  'key',
#  'Western',
#  'Pacific',
#  'islands',
#  '.',
#  '\n\n',
#  'The',
#  'war',
#  'in',
#  'Europe',
#  'concluded',
#  'with',
#  'an',
#  'invasion',
#  'of',
#  'Germany',
#  'by',
#  'the',
#  'Western',
#  'Allies',
#  'and',
#  'the',
#  'Soviet',
#  'Union',
#  ',',
#  'culminating',
#  'in',
#  'the',
#  'capture',
#  'of',
#  'Berlin',
#  'by',
#  'Soviet',
#  'troops',
#  ',',
#  'the',
#  'suicide',
#  'of',
#  'Adolf',
#  'Hitler',
#  'and',
#  'the',
#  'German',
#  'unconditional',
#  'surrender',
#  'on',
#  '8',
#  'May',
#  '1945',
#  '.',
#  'Following',
#  'the',
#  'Potsdam',
#  'Declaration',
#  'by',
#  'the',
#  'Allies',
#  'on',
#  '26',
#  'July',
#  '1945',
#  'and',
#  'the',
#  'refusal',
#  'of',
#  'Japan',
#  'to',
#  'surrender',
#  'under',
#  'its',
#  'terms',
#  ',',
#  'the',
#  'United',
#  'States',
#  'dropped',
#  'atomic',
#  'bombs',
#  'on',
#  'the',
#  'Japanese',
#  'cities',
#  'of',
#  'Hiroshima',
#  'and',
#  'Nagasaki',
#  'on',
#  '6',
#  'and',
#  '9',
#  'August',
#  ',',
#  'respectively',
#  '.',
#  'With',
#  'an',
#  'invasion',
#  'of',
#  'the',
#  'Japanese',
#  'archipelago',
#  'imminent',
#  ',',
#  'the',
#  'possibility',
#  'of',
#  'additional',
#  'atomic',
#  'bombings',
#  ',',
#  'the',
#  'Soviet',
#  'entry',
#  'into',
#  'the',
#  'war',
#  'against',
#  'Japan',
#  'and',
#  'its',
#  'invasion',
#  'of',
#  'Manchuria',
#  ',',
#  'Japan',
#  'announced',
#  'its',
#  'intention',
#  'to',
#  'surrender',
#  'on',
#  '15',
#  'August',
#  '1945',
#  ',',
#  'cementing',
#  'total',
#  'victory',
#  'in',
#  'Asia',
#  'for',
#  'the',
#  'Allies',
#  '.',
#  'Tribunals',
#  'were',
#  'set',
#  'up',
#  'by',
#  'the',
#  'Allies',
#  ',',
#  'and',
#  'war',
#  'crimes',
#  'trials',
#  'were',
#  'conducted',
#  'in',
#  'the',
#  'wake',
#  'of',
#  'the',
#  'war',
#  'both',
#  'against',
#  'the',
#  'Germans',
#  'and',
#  'against',
#  'the',
#  'Japanese',
#  '.',
#  '\n\n',
#  'World',
#  'War',
#  'II',
#  'changed',
#  'the',
#  'political',
#  'alignment',
#  'and',
#  'social',
#  'structure',
#  'of',
#  'the',
#  'globe',
#  '.',
#  'The',
#  'United',
#  'Nations',
#  '(',
#  'UN',
#  ')',
#  'was',
#  'established',
#  'to',
#  'foster',
#  'international',
#  'co',
#  '-',
#  'operation',
#  'and',
#  'prevent',
#  'future',
#  'conflicts',
#  ';',
#  'the',
#  'victorious',
#  'great',
#  'powers',
#  '—',
#  'China',
#  ',',
#  'France',
#  ',',
#  'the',
#  'Soviet',
#  'Union',
#  ',',
#  'the',
#  'United',
#  'Kingdom',
#  ',',
#  'and',
#  'the',
#  'United',
#  'States',
#  '—',
#  'became',
#  'the',
#  'permanent',
#  'members',
#  'of',
#  'its',
#  'Security',
#  'Council',
#  '.',
#  'The',
#  'Soviet',
#  'Union',
#  'and',
#  'the',
#  'United',
#  'States',
#  'emerged',
#  'as',
#  'rival',
#  'superpowers',
#  ',',
#  'setting',
#  'the',
#  'stage',
#  'for',
#  'the',
#  'nearly',
#  'half',
#  '-',
#  'century',
#  '-',
#  'long',
#  'Cold',
#  'War',
#  '.',
#  'In',
#  'the',
#  'wake',
#  'of',
#  'European',
#  'devastation',
#  ',',
#  'the',
#  'influence',
#  'of',
#  'its',
#  'great',
#  'powers',
#  'waned',
#  ',',
#  'triggering',
#  'the',
#  'decolonisation',
#  'of',
#  'Africa',
#  'and',
#  'Asia',
#  '.',
#  'Most',
#  'countries',
#  'whose',
#  'industries',
#  'had',
#  'been',
#  'damaged',
#  'moved',
#  'towards',
#  'economic',
#  'recovery',
#  'and',
#  'expansion',
#  '.',
#  'Political',
#  'integration',
#  ',',
#  'especially',
#  'in',
#  'Europe',
#  ',',
#  'began',
#  'as',
#  'an',
#  'effort',
#  'to',
#  'forestall',
#  'future',
#  'hostilities',
#  ',',
#  'end',
#  'pre',
#  '-',
#  'war',
#  'enmities',
#  'and',
#  'forge',
#  'a',
#  'sense',
#  'of',
#  'common',
#  'identity',
#  '.']

# %%
punctuation=punctuation+"\n"

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n'

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-abb9dba0441a> in <module>()
#       6         word_freq[word.text]=1
#       7       else  :
# ----> 8          word_freq[word.text]+=1
#       9
#
# KeyError: 'States'

# %%
word_freword_freq={}
for word in doc:
  if word.text.lower() not in spacy_stopwords:
    if word.text.lower() not in punctuation:
      if word.text.lower() not in word_freq.keys():
        word_freq[word.text]=1
      else:
        word_freq[word.text]=word_freq[word.text]+1

# %%
word_freq
# Out:
# {'\n\n': 5,
#  '1': 2,
#  '100': 2,
#  '15': 2,
#  '1939': 5,
#  '1941': 4,
#  '1942': 2,
#  '1943—which': 2,
#  '1944': 3,
#  '1945': 6,
#  '22': 2,
#  '26': 2,
#  '30': 2,
#  '6': 2,
#  '70': 2,
#  '8': 2,
#  '85': 2,
#  '9': 2,
#  'Adolf': 1,
#  'Africa': 1,
#  'Aircraft': 1,
#  'Allied': 1,
#  'Allies': 8,
#  'Asia': 1,
#  'Atlantic': 1,
#  'August': 1,
#  'Axis': 1,
#  'Balkans': 1,
#  'Baltic': 1,
#  'Battle': 1,
#  'Berlin': 1,
#  'Blitz': 1,
#  'Britain': 1,
#  'British': 1,
#  'Burma': 1,
#  'Central': 1,
#  'China': 1,
#  'Cold': 1,
#  'Coral': 1,
#  'Council': 1,
#  'December': 1,
#  'Declaration': 2,
#  'East': 1,
#  'Eastern': 1,
#  'Empire': 1,
#  'Europe': 1,
#  'European': 1,
#  'Fall': 1,
#  'Finland': 1,
#  'Following': 1,
#  'France': 1,
#  'German': 1,
#  'Germans': 1,
#  'Germany': 1,
#  'Great': 2,
#  'Guadalcanal': 1,
#  'Hiroshima': 1,
#  'Hitler': 1,
#  'Holocaust': 1,
#  'II': 1,
#  'Italy': 1,
#  'Japan': 1,
#  'Japanese': 1,
#  'Japanese.[1': 1,
#  'July': 1,
#  'June': 1,
#  'Key': 2,
#  'Kingdom': 1,
#  'Manchuria': 1,
#  'Midway': 1,
#  'Molotov': 1,
#  'Nagasaki': 1,
#  'Nations': 1,
#  'Navy': 1,
#  'North': 1,
#  'Pacific': 1,
#  'Pact': 1,
#  'Poland': 1,
#  'Political': 2,
#  'Potsdam': 1,
#  'Ribbentrop': 1,
#  'Romania': 1,
#  'Sea': 1,
#  'Second': 1,
#  'Security': 1,
#  'September': 1,
#  'Sicily': 1,
#  'South': 1,
#  'Soviet': 1,
#  'Stalingrad': 1,
#  'States': 6,
#  'Subsequent': 2,
#  'Tens': 1,
#  'Tribunals': 1,
#  'UN': 1,
#  'Union': 1,
#  'United': 1,
#  'WW2': 1,
#  'WWII': 1,
#  'War': 8,
#  'Wehrmacht': 1,
#  'Western': 1,
#  'World': 6,
#  'abbreviated': 2,
#  'additional': 2,
#  'advances': 2,
#  'aerial': 2,
#  'alignment': 2,
#  'alliance': 2,
#  'alliances': 2,
#  'allies': 2,
#  'ally': 2,
#  'annexed': 2,
#  'announced': 2,
#  'archipelago': 2,
#  'atomic': 3,
#  'attack': 2,
#  'attrition': 2,
#  'began': 2,
#  'begun': 2,
#  'blurring': 2,
#  'bombing': 3,
#  'bombings': 2,
#  'bombs': 2,
#  'campaigns': 3,
#  'capabilities': 2,
#  'capture': 2,
#  'captured': 3,
#  'cementing': 2,
#  'century': 2,
#  'changed': 2,
#  'cities': 2,
#  'civilian': 2,
#  'co': 2,
#  'colonies': 2,
#  'common': 2,
#  'concluded': 2,
#  'conducted': 2,
#  'conflict': 4,
#  'conflicts': 2,
#  'conquered': 2,
#  'continental': 2,
#  'continued': 2,
#  'controlled': 2,
#  'cost': 2,
#  'countries': 4,
#  'crimes': 3,
#  'crippled': 2,
#  'crucially': 2,
#  'culminating': 2,
#  'damaged': 2,
#  'deadliest': 2,
#  'death': 2,
#  'decisively': 2,
#  'declaration': 2,
#  'declarations': 2,
#  'declared': 2,
#  'decolonisation': 2,
#  'defeated': 2,
#  'defeats': 3,
#  'devastation': 2,
#  'died': 2,
#  'directly': 2,
#  'disease': 2,
#  'distinction': 2,
#  'dropped': 2,
#  'early': 2,
#  'economic': 3,
#  'effort': 3,
#  'emerged': 3,
#  'end': 2,
#  'enmities': 2,
#  'entire': 2,
#  'entry': 2,
#  'especially': 2,
#  'established': 2,
#  'eventually': 2,
#  'expansion': 2,
#  'fatalities': 2,
#  'followed': 2,
#  'forced': 2,
#  'forestall': 2,
#  'forge': 2,
#  'formed': 3,
#  'foster': 2,
#  'frequently': 2,
#  'fronts': 2,
#  'future': 3,
#  'generally': 2,
#  'genocides': 2,
#  'global': 2,
#  'globe': 2,
#  'great': 4,
#  'half': 2,
#  'halted': 2,
#  'history': 3,
#  'hostilities': 2,
#  'human': 2,
#  'identity': 2,
#  'immediate': 2,
#  'imminent': 2,
#  'imperialism': 2,
#  'included': 3,
#  'including': 3,
#  'industrial': 2,
#  'industries': 2,
#  'influence': 2,
#  'initially': 2,
#  'initiative': 2,
#  'integration': 2,
#  'intention': 2,
#  'international': 2,
#  'invaded': 2,
#  'invasion': 6,
#  'invasions': 2,
#  'involving': 2,
#  'islands': 2,
#  'key': 2,
#  'known': 2,
#  'land': 2,
#  'largest': 2,
#  'lasted': 2,
#  'late': 2,
#  'later': 2,
#  'launched': 3,
#  'liberators': 2,
#  'local': 2,
#  'long': 3,
#  'losses': 2,
#  'mainland': 2,
#  'major': 4,
#  'majority': 2,
#  'marked': 2,
#  'massacres': 2,
#  'members': 2,
#  'mid-1940': 2,
#  'military': 3,
#  'million': 3,
#  'millions': 2,
#  'moved': 2,
#  'nearly': 2,
#  'neighbours': 2,
#  'nuclear': 2,
#  'occupied': 2,
#  'offensives': 2,
#  'onset': 2,
#  'opening': 2,
#  'operation': 2,
#  'opinion': 2,
#  'opposing': 2,
#  'participants': 2,
#  'partitioned': 2,
#  'people': 3,
#  'permanent': 2,
#  'played': 2,
#  'political': 2,
#  'possibility': 2,
#  'powers': 7,
#  'pre': 2,
#  'premeditated': 2,
#  'prevent': 2,
#  'primarily': 2,
#  'public': 2,
#  'quickly': 2,
#  'recovery': 2,
#  'refusal': 2,
#  'regained': 2,
#  'region': 2,
#  'resources': 2,
#  'respectively': 2,
#  'retreat': 2,
#  'reversals': 2,
#  'rival': 2,
#  'role': 2,
#  'said': 2,
#  'scientific': 2,
#  'sense': 2,
#  'series': 3,
#  'set': 2,
#  'setbacks': 2,
#  'setting': 2,
#  'social': 2,
#  'solidarity': 2,
#  'soon': 2,
#  'stage': 2,
#  'starvation': 2,
#  'state': 2,
#  'states': 2,
#  'strategic': 3,
#  'structure': 2,
#  'subsequent': 2,
#  'suffered': 2,
#  'suicide': 2,
#  'superpowers': 2,
#  'supported': 2,
#  'surprise': 2,
#  'surrender': 4,
#  'terms': 2,
#  'territorial': 2,
#  'territories': 2,
#  'terror': 2,
#  'theatre': 2,
#  'threw': 2,
#  'total': 3,
#  'trapped': 2,
#  'treaties': 2,
#  'trials': 2,
#  'triggering': 2,
#  'troops': 2,
#  'turned': 3,
#  'unconditional': 2,
#  'use': 3,
#  'vast': 2,
#  'victorious': 2,
#  'victory': 2,
#  'wake': 3,
#  'waned': 2,
#  'war': 17,
#  'weapons': 2,
#  'welcomed': 2,
#  'world': 2,
#  '–': 2,
#  '—': 6}

# %%
max_freq=max(word_freq.values())

# %%
max_freq
# Out:
# 17

# %%
#NORMALIZED FREQ
for word in word_freq.keys():
   word_freq[word]=word_freq[word]/max_freq

# %%
word_freq
# Out:
# {'\n\n': 0.29411764705882354,
#  '1': 0.11764705882352941,
#  '100': 0.11764705882352941,
#  '15': 0.11764705882352941,
#  '1939': 0.29411764705882354,
#  '1941': 0.23529411764705882,
#  '1942': 0.11764705882352941,
#  '1943—which': 0.11764705882352941,
#  '1944': 0.17647058823529413,
#  '1945': 0.35294117647058826,
#  '22': 0.11764705882352941,
#  '26': 0.11764705882352941,
#  '30': 0.11764705882352941,
#  '6': 0.11764705882352941,
#  '70': 0.11764705882352941,
#  '8': 0.11764705882352941,
#  '85': 0.11764705882352941,
#  '9': 0.11764705882352941,
#  'Adolf': 0.058823529411764705,
#  'Africa': 0.058823529411764705,
#  'Aircraft': 0.058823529411764705,
#  'Allied': 0.058823529411764705,
#  'Allies': 0.47058823529411764,
#  'Asia': 0.058823529411764705,
#  'Atlantic': 0.058823529411764705,
#  'August': 0.058823529411764705,
#  'Axis': 0.058823529411764705,
#  'Balkans': 0.058823529411764705,
#  'Baltic': 0.058823529411764705,
#  'Battle': 0.058823529411764705,
#  'Berlin': 0.058823529411764705,
#  'Blitz': 0.058823529411764705,
#  'Britain': 0.058823529411764705,
#  'British': 0.058823529411764705,
#  'Burma': 0.058823529411764705,
#  'Central': 0.058823529411764705,
#  'China': 0.058823529411764705,
#  'Cold': 0.058823529411764705,
#  'Coral': 0.058823529411764705,
#  'Council': 0.058823529411764705,
#  'December': 0.058823529411764705,
#  'Declaration': 0.11764705882352941,
#  'East': 0.058823529411764705,
#  'Eastern': 0.058823529411764705,
#  'Empire': 0.058823529411764705,
#  'Europe': 0.058823529411764705,
#  'European': 0.058823529411764705,
#  'Fall': 0.058823529411764705,
#  'Finland': 0.058823529411764705,
#  'Following': 0.058823529411764705,
#  'France': 0.058823529411764705,
#  'German': 0.058823529411764705,
#  'Germans': 0.058823529411764705,
#  'Germany': 0.058823529411764705,
#  'Great': 0.11764705882352941,
#  'Guadalcanal': 0.058823529411764705,
#  'Hiroshima': 0.058823529411764705,
#  'Hitler': 0.058823529411764705,
#  'Holocaust': 0.058823529411764705,
#  'II': 0.058823529411764705,
#  'Italy': 0.058823529411764705,
#  'Japan': 0.058823529411764705,
#  'Japanese': 0.058823529411764705,
#  'Japanese.[1': 0.058823529411764705,
#  'July': 0.058823529411764705,
#  'June': 0.058823529411764705,
#  'Key': 0.11764705882352941,
#  'Kingdom': 0.058823529411764705,
#  'Manchuria': 0.058823529411764705,
#  'Midway': 0.058823529411764705,
#  'Molotov': 0.058823529411764705,
#  'Nagasaki': 0.058823529411764705,
#  'Nations': 0.058823529411764705,
#  'Navy': 0.058823529411764705,
#  'North': 0.058823529411764705,
#  'Pacific': 0.058823529411764705,
#  'Pact': 0.058823529411764705,
#  'Poland': 0.058823529411764705,
#  'Political': 0.11764705882352941,
#  'Potsdam': 0.058823529411764705,
#  'Ribbentrop': 0.058823529411764705,
#  'Romania': 0.058823529411764705,
#  'Sea': 0.058823529411764705,
#  'Second': 0.058823529411764705,
#  'Security': 0.058823529411764705,
#  'September': 0.058823529411764705,
#  'Sicily': 0.058823529411764705,
#  'South': 0.058823529411764705,
#  'Soviet': 0.058823529411764705,
#  'Stalingrad': 0.058823529411764705,
#  'States': 0.35294117647058826,
#  'Subsequent': 0.11764705882352941,
#  'Tens': 0.058823529411764705,
#  'Tribunals': 0.058823529411764705,
#  'UN': 0.058823529411764705,
#  'Union': 0.058823529411764705,
#  'United': 0.058823529411764705,
#  'WW2': 0.058823529411764705,
#  'WWII': 0.058823529411764705,
#  'War': 0.47058823529411764,
#  'Wehrmacht': 0.058823529411764705,
#  'Western': 0.058823529411764705,
#  'World': 0.35294117647058826,
#  'abbreviated': 0.11764705882352941,
#  'additional': 0.11764705882352941,
#  'advances': 0.11764705882352941,
#  'aerial': 0.11764705882352941,
#  'alignment': 0.11764705882352941,
#  'alliance': 0.11764705882352941,
#  'alliances': 0.11764705882352941,
#  'allies': 0.11764705882352941,
#  'ally': 0.11764705882352941,
#  'annexed': 0.11764705882352941,
#  'announced': 0.11764705882352941,
#  'archipelago': 0.11764705882352941,
#  'atomic': 0.17647058823529413,
#  'attack': 0.11764705882352941,
#  'attrition': 0.11764705882352941,
#  'began': 0.11764705882352941,
#  'begun': 0.11764705882352941,
#  'blurring': 0.11764705882352941,
#  'bombing': 0.17647058823529413,
#  'bombings': 0.11764705882352941,
#  'bombs': 0.11764705882352941,
#  'campaigns': 0.17647058823529413,
#  'capabilities': 0.11764705882352941,
#  'capture': 0.11764705882352941,
#  'captured': 0.17647058823529413,
#  'cementing': 0.11764705882352941,
#  'century': 0.11764705882352941,
#  'changed': 0.11764705882352941,
#  'cities': 0.11764705882352941,
#  'civilian': 0.11764705882352941,
#  'co': 0.11764705882352941,
#  'colonies': 0.11764705882352941,
#  'common': 0.11764705882352941,
#  'concluded': 0.11764705882352941,
#  'conducted': 0.11764705882352941,
#  'conflict': 0.23529411764705882,
#  'conflicts': 0.11764705882352941,
#  'conquered': 0.11764705882352941,
#  'continental': 0.11764705882352941,
#  'continued': 0.11764705882352941,
#  'controlled': 0.11764705882352941,
#  'cost': 0.11764705882352941,
#  'countries': 0.23529411764705882,
#  'crimes': 0.17647058823529413,
#  'crippled': 0.11764705882352941,
#  'crucially': 0.11764705882352941,
#  'culminating': 0.11764705882352941,
#  'damaged': 0.11764705882352941,
#  'deadliest': 0.11764705882352941,
#  'death': 0.11764705882352941,
#  'decisively': 0.11764705882352941,
#  'declaration': 0.11764705882352941,
#  'declarations': 0.11764705882352941,
#  'declared': 0.11764705882352941,
#  'decolonisation': 0.11764705882352941,
#  'defeated': 0.11764705882352941,
#  'defeats': 0.17647058823529413,
#  'devastation': 0.11764705882352941,
#  'died': 0.11764705882352941,
#  'directly': 0.11764705882352941,
#  'disease': 0.11764705882352941,
#  'distinction': 0.11764705882352941,
#  'dropped': 0.11764705882352941,
#  'early': 0.11764705882352941,
#  'economic': 0.17647058823529413,
#  'effort': 0.17647058823529413,
#  'emerged': 0.17647058823529413,
#  'end': 0.11764705882352941,
#  'enmities': 0.11764705882352941,
#  'entire': 0.11764705882352941,
#  'entry': 0.11764705882352941,
#  'especially': 0.11764705882352941,
#  'established': 0.11764705882352941,
#  'eventually': 0.11764705882352941,
#  'expansion': 0.11764705882352941,
#  'fatalities': 0.11764705882352941,
#  'followed': 0.11764705882352941,
#  'forced': 0.11764705882352941,
#  'forestall': 0.11764705882352941,
#  'forge': 0.11764705882352941,
#  'formed': 0.17647058823529413,
#  'foster': 0.11764705882352941,
#  'frequently': 0.11764705882352941,
#  'fronts': 0.11764705882352941,
#  'future': 0.17647058823529413,
#  'generally': 0.11764705882352941,
#  'genocides': 0.11764705882352941,
#  'global': 0.11764705882352941,
#  'globe': 0.11764705882352941,
#  'great': 0.23529411764705882,
#  'half': 0.11764705882352941,
#  'halted': 0.11764705882352941,
#  'history': 0.17647058823529413,
#  'hostilities': 0.11764705882352941,
#  'human': 0.11764705882352941,
#  'identity': 0.11764705882352941,
#  'immediate': 0.11764705882352941,
#  'imminent': 0.11764705882352941,
#  'imperialism': 0.11764705882352941,
#  'included': 0.17647058823529413,
#  'including': 0.17647058823529413,
#  'industrial': 0.11764705882352941,
#  'industries': 0.11764705882352941,
#  'influence': 0.11764705882352941,
#  'initially': 0.11764705882352941,
#  'initiative': 0.11764705882352941,
#  'integration': 0.11764705882352941,
#  'intention': 0.11764705882352941,
#  'international': 0.11764705882352941,
#  'invaded': 0.11764705882352941,
#  'invasion': 0.35294117647058826,
#  'invasions': 0.11764705882352941,
#  'involving': 0.11764705882352941,
#  'islands': 0.11764705882352941,
#  'key': 0.11764705882352941,
#  'known': 0.11764705882352941,
#  'land': 0.11764705882352941,
#  'largest': 0.11764705882352941,
#  'lasted': 0.11764705882352941,
#  'late': 0.11764705882352941,
#  'later': 0.11764705882352941,
#  'launched': 0.17647058823529413,
#  'liberators': 0.11764705882352941,
#  'local': 0.11764705882352941,
#  'long': 0.17647058823529413,
#  'losses': 0.11764705882352941,
#  'mainland': 0.11764705882352941,
#  'major': 0.23529411764705882,
#  'majority': 0.11764705882352941,
#  'marked': 0.11764705882352941,
#  'massacres': 0.11764705882352941,
#  'members': 0.11764705882352941,
#  'mid-1940': 0.11764705882352941,
#  'military': 0.17647058823529413,
#  'million': 0.17647058823529413,
#  'millions': 0.11764705882352941,
#  'moved': 0.11764705882352941,
#  'nearly': 0.11764705882352941,
#  'neighbours': 0.11764705882352941,
#  'nuclear': 0.11764705882352941,
#  'occupied': 0.11764705882352941,
#  'offensives': 0.11764705882352941,
#  'onset': 0.11764705882352941,
#  'opening': 0.11764705882352941,
#  'operation': 0.11764705882352941,
#  'opinion': 0.11764705882352941,
#  'opposing': 0.11764705882352941,
#  'participants': 0.11764705882352941,
#  'partitioned': 0.11764705882352941,
#  'people': 0.17647058823529413,
#  'permanent': 0.11764705882352941,
#  'played': 0.11764705882352941,
#  'political': 0.11764705882352941,
#  'possibility': 0.11764705882352941,
#  'powers': 0.4117647058823529,
#  'pre': 0.11764705882352941,
#  'premeditated': 0.11764705882352941,
#  'prevent': 0.11764705882352941,
#  'primarily': 0.11764705882352941,
#  'public': 0.11764705882352941,
#  'quickly': 0.11764705882352941,
#  'recovery': 0.11764705882352941,
#  'refusal': 0.11764705882352941,
#  'regained': 0.11764705882352941,
#  'region': 0.11764705882352941,
#  'resources': 0.11764705882352941,
#  'respectively': 0.11764705882352941,
#  'retreat': 0.11764705882352941,
#  'reversals': 0.11764705882352941,
#  'rival': 0.11764705882352941,
#  'role': 0.11764705882352941,
#  'said': 0.11764705882352941,
#  'scientific': 0.11764705882352941,
#  'sense': 0.11764705882352941,
#  'series': 0.17647058823529413,
#  'set': 0.11764705882352941,
#  'setbacks': 0.11764705882352941,
#  'setting': 0.11764705882352941,
#  'social': 0.11764705882352941,
#  'solidarity': 0.11764705882352941,
#  'soon': 0.11764705882352941,
#  'stage': 0.11764705882352941,
#  'starvation': 0.11764705882352941,
#  'state': 0.11764705882352941,
#  'states': 0.11764705882352941,
#  'strategic': 0.17647058823529413,
#  'structure': 0.11764705882352941,
#  'subsequent': 0.11764705882352941,
#  'suffered': 0.11764705882352941,
#  'suicide': 0.11764705882352941,
#  'superpowers': 0.11764705882352941,
#  'supported': 0.11764705882352941,
#  'surprise': 0.11764705882352941,
#  'surrender': 0.23529411764705882,
#  'terms': 0.11764705882352941,
#  'territorial': 0.11764705882352941,
#  'territories': 0.11764705882352941,
#  'terror': 0.11764705882352941,
#  'theatre': 0.11764705882352941,
#  'threw': 0.11764705882352941,
#  'total': 0.17647058823529413,
#  'trapped': 0.11764705882352941,
#  'treaties': 0.11764705882352941,
#  'trials': 0.11764705882352941,
#  'triggering': 0.11764705882352941,
#  'troops': 0.11764705882352941,
#  'turned': 0.17647058823529413,
#  'unconditional': 0.11764705882352941,
#  'use': 0.17647058823529413,
#  'vast': 0.11764705882352941,
#  'victorious': 0.11764705882352941,
#  'victory': 0.11764705882352941,
#  'wake': 0.17647058823529413,
#  'waned': 0.11764705882352941,
#  'war': 1.0,
#  'weapons': 0.11764705882352941,
#  'welcomed': 0.11764705882352941,
#  'world': 0.11764705882352941,
#  '–': 0.11764705882352941,
#  '—': 0.35294117647058826}

# %%
sent_tokens=[sent for sent in doc.sents]

# %%
sent_tokens
# Out:
# [World War II (often abbreviated as WWII or WW2), also known as the Second World War, was a global war that lasted from 1939 to 1945.,
#  The vast majority of the world's countries—including all the great powers—eventually formed two opposing military alliances: the Allies and the Axis.,
#  A state of total war emerged, directly involving more than 100 million people from more than 30 countries.,
#  The major participants threw their entire economic, industrial, and scientific capabilities behind the war effort, blurring the distinction between civilian and military resources.,
#  World War II was the deadliest conflict in human history, marked by 70 to 85 million fatalities.,
#  Tens of millions of people died during the conflict due to genocides (including the Holocaust), premeditated death from starvation, massacres, and disease.,
#  Aircraft played a major role in the conflict which included the use of terror bombing, strategic bombing and the only use of nuclear weapons in war.
#  ,
#  World War II is generally said to have begun on 1 September 1939, with the invasion of Poland by Germany and subsequent declarations of war on Germany by France and the United Kingdom.,
#  From late 1939 to early 1941, in a series of campaigns and treaties, Germany conquered or controlled much of continental Europe, and formed the Axis alliance with Italy and Japan.,
#  Under the Molotov–Ribbentrop Pact of August 1939, Germany and the Soviet Union partitioned and annexed territories of their European neighbours, Poland, Finland, Romania and the Baltic states.,
#  Following the onset of campaigns in North Africa and East Africa, and the Fall of France in mid-1940, the war continued primarily between the European Axis powers and the British Empire.,
#  War in the Balkans, the aerial Battle of Britain, the Blitz, and the long Battle of the Atlantic followed.,
#  On 22 June 1941, the European Axis powers launched an invasion of the Soviet Union, opening the largest land theatre of war in history.,
#  This Eastern Front trapped the Axis, most crucially the German Wehrmacht, in a war of attrition.
#  ,
#  In December 1941 Japan launched a surprise attack on the United States as well as European colonies in East Asia and the Pacific.,
#  Following an immediate US declaration of war against Japan, supported by one from Great Britain, the European Axis powers quickly declared war on the United States in solidarity with their Japanese ally.,
#  Japan soon captured much of the Western Pacific.,
#  Some in the region initially welcomed the Japanese as liberators from Western imperialism.,
#  Subsequent Japanese war crimes frequently turned local public opinion against the Japanese.[1],
#  Japan's advances in the Pacific were halted in 1942 after defeats at the Battle of Midway, Battle of the Coral Sea and Battle of Guadalcanal; later, Germany and Italy were defeated in North Africa and then, decisively, at Stalingrad in the Soviet Union.,
#  Key setbacks in 1943—which included a series of German defeats on the Eastern Front, the Allied invasions of Sicily and Italy, and Allied offensives in the Pacific—cost the Axis its initiative and forced it into strategic retreat on all fronts.,
#  In 1944 the Western Allies invaded German-occupied France, while the Soviet Union regained its territorial losses and turned toward Germany and its allies.,
#  During 1944 and 1945 the Japanese suffered major reversals in mainland Asia, in Central China, South China and Burma, while the Allies crippled the Japanese Navy and captured key Western Pacific islands.
#  ,
#  The war in Europe concluded with an invasion of Germany by the Western Allies and the Soviet Union, culminating in the capture of Berlin by Soviet troops, the suicide of Adolf Hitler and the German unconditional surrender on 8 May 1945.,
#  Following the Potsdam Declaration by the Allies on 26 July 1945 and the refusal of Japan to surrender under its terms, the United States dropped atomic bombs on the Japanese cities of Hiroshima and Nagasaki on 6 and 9 August, respectively.,
#  With an invasion of the Japanese archipelago imminent, the possibility of additional atomic bombings, the Soviet entry into the war against Japan and its invasion of Manchuria, Japan announced its intention to surrender on 15 August 1945, cementing total victory in Asia for the Allies.,
#  Tribunals were set up by the Allies, and war crimes trials were conducted in the wake of the war both against the Germans and against the Japanese.
#  ,
#  World War II changed the political alignment and social structure of the globe.,
#  The United Nations (UN) was established to foster international co-operation and prevent future conflicts; the victorious great powers—China, France, the Soviet Union, the United Kingdom, and the United States—became the permanent members of its Security Council.,
#  The Soviet Union and the United States emerged as rival superpowers, setting the stage for the nearly half-century-long Cold War.,
#  In the wake of European devastation, the influence of its great powers waned, triggering the decolonisation of Africa and Asia.,
#  Most countries whose industries had been damaged moved towards economic recovery and expansion.,
#  Political integration, especially in Europe, began as an effort to forestall future hostilities, end pre-war enmities and forge a sense of common identity.]

# %%
sent_scores={}
for sent in sent_tokens:
  for word in sent:
    if word.text.lower() in word_freq.keys():
      if sent not in sent_scores.keys():
        sent_scores[sent]=word_freq[word.text.lower()]
      else:
        sent_scores[sent]==word_freq[word.text.lower()]+ sent_scores[sent]

# %%
sent_scores
# Out:
# {World War II (often abbreviated as WWII or WW2), also known as the Second World War, was a global war that lasted from 1939 to 1945.: 0.11764705882352941,
#  The vast majority of the world's countries—including all the great powers—eventually formed two opposing military alliances: the Allies and the Axis.: 0.11764705882352941,
#  A state of total war emerged, directly involving more than 100 million people from more than 30 countries.: 0.11764705882352941,
#  The major participants threw their entire economic, industrial, and scientific capabilities behind the war effort, blurring the distinction between civilian and military resources.: 0.23529411764705882,
#  World War II was the deadliest conflict in human history, marked by 70 to 85 million fatalities.: 0.11764705882352941,
#  Tens of millions of people died during the conflict due to genocides (including the Holocaust), premeditated death from starvation, massacres, and disease.: 0.11764705882352941,
#  Aircraft played a major role in the conflict which included the use of terror bombing, strategic bombing and the only use of nuclear weapons in war.
#  : 0.11764705882352941,
#  World War II is generally said to have begun on 1 September 1939, with the invasion of Poland by Germany and subsequent declarations of war on Germany by France and the United Kingdom.: 0.11764705882352941,
#  From late 1939 to early 1941, in a series of campaigns and treaties, Germany conquered or controlled much of continental Europe, and formed the Axis alliance with Italy and Japan.: 0.11764705882352941,
#  Under the Molotov–Ribbentrop Pact of August 1939, Germany and the Soviet Union partitioned and annexed territories of their European neighbours, Poland, Finland, Romania and the Baltic states.: 0.11764705882352941,
#  Following the onset of campaigns in North Africa and East Africa, and the Fall of France in mid-1940, the war continued primarily between the European Axis powers and the British Empire.: 0.11764705882352941,
#  War in the Balkans, the aerial Battle of Britain, the Blitz, and the long Battle of the Atlantic followed.: 1.0,
#  On 22 June 1941, the European Axis powers launched an invasion of the Soviet Union, opening the largest land theatre of war in history.: 0.11764705882352941,
#  This Eastern Front trapped the Axis, most crucially the German Wehrmacht, in a war of attrition.
#  : 0.11764705882352941,
#  In December 1941 Japan launched a surprise attack on the United States as well as European colonies in East Asia and the Pacific.: 0.23529411764705882,
#  Following an immediate US declaration of war against Japan, supported by one from Great Britain, the European Axis powers quickly declared war on the United States in solidarity with their Japanese ally.: 0.11764705882352941,
#  Japan soon captured much of the Western Pacific.: 0.11764705882352941,
#  Some in the region initially welcomed the Japanese as liberators from Western imperialism.: 0.11764705882352941,
#  Subsequent Japanese war crimes frequently turned local public opinion against the Japanese.[1]: 0.11764705882352941,
#  Japan's advances in the Pacific were halted in 1942 after defeats at the Battle of Midway, Battle of the Coral Sea and Battle of Guadalcanal; later, Germany and Italy were defeated in North Africa and then, decisively, at Stalingrad in the Soviet Union.: 0.11764705882352941,
#  Key setbacks in 1943—which included a series of German defeats on the Eastern Front, the Allied invasions of Sicily and Italy, and Allied offensives in the Pacific—cost the Axis its initiative and forced it into strategic retreat on all fronts.: 0.11764705882352941,
#  In 1944 the Western Allies invaded German-occupied France, while the Soviet Union regained its territorial losses and turned toward Germany and its allies.: 0.17647058823529413,
#  During 1944 and 1945 the Japanese suffered major reversals in mainland Asia, in Central China, South China and Burma, while the Allies crippled the Japanese Navy and captured key Western Pacific islands.
#  : 0.17647058823529413,
#  The war in Europe concluded with an invasion of Germany by the Western Allies and the Soviet Union, culminating in the capture of Berlin by Soviet troops, the suicide of Adolf Hitler and the German unconditional surrender on 8 May 1945.: 1.0,
#  Following the Potsdam Declaration by the Allies on 26 July 1945 and the refusal of Japan to surrender under its terms, the United States dropped atomic bombs on the Japanese cities of Hiroshima and Nagasaki on 6 and 9 August, respectively.: 0.11764705882352941,
#  With an invasion of the Japanese archipelago imminent, the possibility of additional atomic bombings, the Soviet entry into the war against Japan and its invasion of Manchuria, Japan announced its intention to surrender on 15 August 1945, cementing total victory in Asia for the Allies.: 0.35294117647058826,
#  Tribunals were set up by the Allies, and war crimes trials were conducted in the wake of the war both against the Germans and against the Japanese.
#  : 0.11764705882352941,
#  World War II changed the political alignment and social structure of the globe.: 0.11764705882352941,
#  The United Nations (UN) was established to foster international co-operation and prevent future conflicts; the victorious great powers—China, France, the Soviet Union, the United Kingdom, and the United States—became the permanent members of its Security Council.: 0.11764705882352941,
#  The Soviet Union and the United States emerged as rival superpowers, setting the stage for the nearly half-century-long Cold War.: 0.11764705882352941,
#  In the wake of European devastation, the influence of its great powers waned, triggering the decolonisation of Africa and Asia.: 0.17647058823529413,
#  Most countries whose industries had been damaged moved towards economic recovery and expansion.: 0.23529411764705882,
#  Political integration, especially in Europe, began as an effort to forestall future hostilities, end pre-war enmities and forge a sense of common identity.: 0.11764705882352941}

# %%
from heapq import nlargest
select_length=int(len(sent_tokens)*.4)

# %%
select_length
# Out:
# 13

# %%
summary=nlargest(select_length,sent_scores,key=sent_scores.get)

# %%
summary
# Out:
# [War in the Balkans, the aerial Battle of Britain, the Blitz, and the long Battle of the Atlantic followed.,
#  The war in Europe concluded with an invasion of Germany by the Western Allies and the Soviet Union, culminating in the capture of Berlin by Soviet troops, the suicide of Adolf Hitler and the German unconditional surrender on 8 May 1945.,
#  With an invasion of the Japanese archipelago imminent, the possibility of additional atomic bombings, the Soviet entry into the war against Japan and its invasion of Manchuria, Japan announced its intention to surrender on 15 August 1945, cementing total victory in Asia for the Allies.,
#  The major participants threw their entire economic, industrial, and scientific capabilities behind the war effort, blurring the distinction between civilian and military resources.,
#  In December 1941 Japan launched a surprise attack on the United States as well as European colonies in East Asia and the Pacific.,
#  Most countries whose industries had been damaged moved towards economic recovery and expansion.,
#  In 1944 the Western Allies invaded German-occupied France, while the Soviet Union regained its territorial losses and turned toward Germany and its allies.,
#  During 1944 and 1945 the Japanese suffered major reversals in mainland Asia, in Central China, South China and Burma, while the Allies crippled the Japanese Navy and captured key Western Pacific islands.
#  ,
#  In the wake of European devastation, the influence of its great powers waned, triggering the decolonisation of Africa and Asia.,
#  World War II (often abbreviated as WWII or WW2), also known as the Second World War, was a global war that lasted from 1939 to 1945.,
#  The vast majority of the world's countries—including all the great powers—eventually formed two opposing military alliances: the Allies and the Axis.,
#  A state of total war emerged, directly involving more than 100 million people from more than 30 countries.,
#  World War II was the deadliest conflict in human history, marked by 70 to 85 million fatalities.]

# %%
fin_sum=[word.text for word in summary]

# %%
fin_sum
# Out:
# ['War in the Balkans, the aerial Battle of Britain, the Blitz, and the long Battle of the Atlantic followed.',
#  'The war in Europe concluded with an invasion of Germany by the Western Allies and the Soviet Union, culminating in the capture of Berlin by Soviet troops, the suicide of Adolf Hitler and the German unconditional surrender on 8 May 1945.',
#  'With an invasion of the Japanese archipelago imminent, the possibility of additional atomic bombings, the Soviet entry into the war against Japan and its invasion of Manchuria, Japan announced its intention to surrender on 15 August 1945, cementing total victory in Asia for the Allies.',
#  'The major participants threw their entire economic, industrial, and scientific capabilities behind the war effort, blurring the distinction between civilian and military resources.',
#  'In December 1941 Japan launched a surprise attack on the United States as well as European colonies in East Asia and the Pacific.',
#  'Most countries whose industries had been damaged moved towards economic recovery and expansion.',
#  'In 1944 the Western Allies invaded German-occupied France, while the Soviet Union regained its territorial losses and turned toward Germany and its allies.',
#  'During 1944 and 1945 the Japanese suffered major reversals in mainland Asia, in Central China, South China and Burma, while the Allies crippled the Japanese Navy and captured key Western Pacific islands.\n\n',
#  'In the wake of European devastation, the influence of its great powers waned, triggering the decolonisation of Africa and Asia.',
#  'World War II (often abbreviated as WWII or WW2), also known as the Second World War, was a global war that lasted from 1939 to 1945.',
#  "The vast majority of the world's countries—including all the great powers—eventually formed two opposing military alliances: the Allies and the Axis.",
#  'A state of total war emerged, directly involving more than 100 million people from more than 30 countries.',
#  'World War II was the deadliest conflict in human history, marked by 70 to 85 million fatalities.']

# %%
summaryyy=' '.join(fin_sum)

# %%
summaryyy
# Out:
# "War in the Balkans, the aerial Battle of Britain, the Blitz, and the long Battle of the Atlantic followed. The war in Europe concluded with an invasion of Germany by the Western Allies and the Soviet Union, culminating in the capture of Berlin by Soviet troops, the suicide of Adolf Hitler and the German unconditional surrender on 8 May 1945. With an invasion of the Japanese archipelago imminent, the possibility of additional atomic bombings, the Soviet entry into the war against Japan and its invasion of Manchuria, Japan announced its intention to surrender on 15 August 1945, cementing total victory in Asia for the Allies. The major participants threw their entire economic, industrial, and scientific capabilities behind the war effort, blurring the distinction between civilian and military resources. In December 1941 Japan launched a surprise attack on the United States as well as European colonies in East Asia and the Pacific. Most countries whose industries had been damaged moved towards economic recovery and expansion. In 1944 the Western Allies invaded German-occupied France, while the Soviet Union regained its territorial losses and turned toward Germany and its allies. During 1944 and 1945 the Japanese suffered major reversals in mainland Asia, in Central China, South China and Burma, while the Allies crippled the Japanese Navy and captured key Western Pacific islands.\n\n In the wake of European devastation, the influence of its great powers waned, triggering the decolonisation of Africa and Asia. World War II (often abbreviated as WWII or WW2), also known as the Second World War, was a global war that lasted from 1939 to 1945. The vast majority of the world's countries—including all the great powers—eventually formed two opposing military alliances: the Allies and the Axis. A state of total war emerged, directly involving more than 100 million people from more than 30 countries. World War II was the deadliest conflict in human history, marked by 70 to 85 million fatalities."

# %%
len(sent_tokens)
# Out:
# 33

# %%
len(sent_scores)
# Out:
# 33
